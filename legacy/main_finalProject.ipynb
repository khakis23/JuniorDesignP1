# %% [markdown]
# # Project 2: Deep Ensembles

# %% [markdown]
# ## Introduction
#
# This project seeks to accomplish the problem outlined in PyMAISE's Critical Heat Flux (CHF) Prediction benchmark using a deep ensemble model.
